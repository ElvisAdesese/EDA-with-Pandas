# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
meta= pd.read_csv('Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_3158886.csv')

# %%
data = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_3158886.csv', skiprows=4)

# %%
data
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54208.0      55434.0      56234.0      56699.0
# 1      SP.POP.TOTL  130836765.0  134159786.0  137614644.0  141202036.0
# 2      SP.POP.TOTL    8996967.0    9169406.0    9351442.0    9543200.0
# 3      SP.POP.TOTL   96396419.0   98407221.0  100506960.0  102691339.0
# 4      SP.POP.TOTL    5454938.0    5531451.0    5608499.0    5679409.0
# ..             ...          ...          ...          ...          ...
# 261    SP.POP.TOTL     947000.0     966000.0     994000.0    1022000.0
# 262    SP.POP.TOTL    5315351.0    5393034.0    5473671.0    5556767.0
# 263    SP.POP.TOTL   17099836.0   17524533.0   17965733.0   18423157.0
# 264    SP.POP.TOTL    3070780.0    3164330.0    3260645.0    3360099.0
# 265    SP.POP.TOTL    3776679.0    3905038.0    4039209.0    4178726.0
#
#             1964         1965  ...         2012         2013         2014  \
# 0        57029.0      57357.0  ...     102565.0     103165.0     103776.0
# 1    144920186.0  148769974.0  ...  547482863.0  562601578.0  578075373.0
# 2      9744772.0    9956318.0  ...   31161378.0   32269592.0   33370804.0
# 3    104953470.0  107289875.0  ...  370243017.0  380437896.0  390882979.0
# 4      5734995.0    5770573.0  ...   25107925.0   26015786.0   26941773.0
# ..           ...          ...  ...          ...          ...          ...
# 261    1050000.0    1078000.0  ...    1807106.0    1818117.0    1812771.0
# 262    5641598.0    5727745.0  ...   24473176.0   25147112.0   25823488.0
# 263   18896303.0   19384838.0  ...   52832659.0   53687125.0   54544184.0
# 264    3463211.0    3570466.0  ...   14465148.0   14926551.0   15399793.0
# 265    4322854.0    4471178.0  ...   13115149.0   13350378.0   13586710.0
#
#             2015         2016         2017         2018         2019  \
# 0       104339.0     104865.0     105361.0     105846.0     106310.0
# 1    593871847.0  609978946.0  626392880.0  643090131.0  660046272.0
# 2     34413603.0   35383028.0   36296111.0   37171922.0   38041757.0
# 3    401586651.0  412551299.0  423769930.0  435229381.0  446911598.0
# 4     27884380.0   28842482.0   29816769.0   30809787.0   31825299.0
# ..           ...          ...          ...          ...          ...
# 261    1788196.0    1777557.0    1791003.0    1797085.0    1788878.0
# 262   26497881.0   27168210.0   27834811.0   28498683.0   29161922.0
# 263   55386369.0   56207649.0   57009751.0   57792520.0   58558267.0
# 264   15879370.0   16363449.0   16853608.0   17351714.0   17861034.0
# 265   13814642.0   14030338.0   14236599.0   14438812.0   14645473.0
#
#             2020  Unnamed: 65
# 0       106766.0          NaN
# 1    677243299.0          NaN
# 2     38928341.0          NaN
# 3    458803476.0          NaN
# 4     32866268.0          NaN
# ..           ...          ...
# 261    1775378.0          NaN
# 262   29825968.0          NaN
# 263   59308690.0          NaN
# 264   18383956.0          NaN
# 265   14862927.0          NaN
#
# [266 rows x 66 columns]

# %%
meta
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# 2    Fiscal year end: March 20; reporting period fo...
# 3    22 countries, stretching from the westernmost ...
# 4                                                  NaN
# ..                                                 ...
# 260                                                NaN
# 261                                                NaN
# 262  Fiscal year end: March 31; reporting period fo...
# 263  National accounts data were rebased to reflect...
# 264                                                NaN
#
#                        TableName  Unnamed: 5
# 0                          Aruba         NaN
# 1    Africa Eastern and Southern         NaN
# 2                    Afghanistan         NaN
# 3     Africa Western and Central         NaN
# 4                         Angola         NaN
# ..                           ...         ...
# 260                       Kosovo         NaN
# 261                  Yemen, Rep.         NaN
# 262                 South Africa         NaN
# 263                       Zambia         NaN
# 264                     Zimbabwe         NaN
#
# [265 rows x 6 columns]

# %%
len(data), len(meta)
# Out:
# (266, 265)

# %%
# df1.merge(df2, how='inner', on='a')

dataset = data.merge(meta, how='inner', on='Country Code')

# %%
dataset
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 260                       Kosovo          XKX  Population, total
# 261                  Yemen, Rep.          YEM  Population, total
# 262                 South Africa          ZAF  Population, total
# 263                       Zambia          ZMB  Population, total
# 264                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54208.0      55434.0      56234.0      56699.0
# 1      SP.POP.TOTL  130836765.0  134159786.0  137614644.0  141202036.0
# 2      SP.POP.TOTL    8996967.0    9169406.0    9351442.0    9543200.0
# 3      SP.POP.TOTL   96396419.0   98407221.0  100506960.0  102691339.0
# 4      SP.POP.TOTL    5454938.0    5531451.0    5608499.0    5679409.0
# ..             ...          ...          ...          ...          ...
# 260    SP.POP.TOTL     947000.0     966000.0     994000.0    1022000.0
# 261    SP.POP.TOTL    5315351.0    5393034.0    5473671.0    5556767.0
# 262    SP.POP.TOTL   17099836.0   17524533.0   17965733.0   18423157.0
# 263    SP.POP.TOTL    3070780.0    3164330.0    3260645.0    3360099.0
# 264    SP.POP.TOTL    3776679.0    3905038.0    4039209.0    4178726.0
#
#             1964         1965  ...         2017         2018         2019  \
# 0        57029.0      57357.0  ...     105361.0     105846.0     106310.0
# 1    144920186.0  148769974.0  ...  626392880.0  643090131.0  660046272.0
# 2      9744772.0    9956318.0  ...   36296111.0   37171922.0   38041757.0
# 3    104953470.0  107289875.0  ...  423769930.0  435229381.0  446911598.0
# 4      5734995.0    5770573.0  ...   29816769.0   30809787.0   31825299.0
# ..           ...          ...  ...          ...          ...          ...
# 260    1050000.0    1078000.0  ...    1791003.0    1797085.0    1788878.0
# 261    5641598.0    5727745.0  ...   27834811.0   28498683.0   29161922.0
# 262   18896303.0   19384838.0  ...   57009751.0   57792520.0   58558267.0
# 263    3463211.0    3570466.0  ...   16853608.0   17351714.0   17861034.0
# 264    4322854.0    4471178.0  ...   14236599.0   14438812.0   14645473.0
#
#             2020  Unnamed: 65                      Region  \
# 0       106766.0          NaN   Latin America & Caribbean
# 1    677243299.0          NaN                         NaN
# 2     38928341.0          NaN                  South Asia
# 3    458803476.0          NaN                         NaN
# 4     32866268.0          NaN          Sub-Saharan Africa
# ..           ...          ...                         ...
# 260    1775378.0          NaN       Europe & Central Asia
# 261   29825968.0          NaN  Middle East & North Africa
# 262   59308690.0          NaN          Sub-Saharan Africa
# 263   18383956.0          NaN          Sub-Saharan Africa
# 264   14862927.0          NaN          Sub-Saharan Africa
#
#              IncomeGroup                                       SpecialNotes  \
# 0            High income                                                NaN
# 1                    NaN  26 countries, stretching from the Red Sea in t...
# 2             Low income  Fiscal year end: March 20; reporting period fo...
# 3                    NaN  22 countries, stretching from the westernmost ...
# 4    Lower middle income                                                NaN
# ..                   ...                                                ...
# 260  Upper middle income                                                NaN
# 261           Low income                                                NaN
# 262  Upper middle income  Fiscal year end: March 31; reporting period fo...
# 263  Lower middle income  National accounts data were rebased to reflect...
# 264  Lower middle income                                                NaN
#
#                        TableName  Unnamed: 5
# 0                          Aruba         NaN
# 1    Africa Eastern and Southern         NaN
# 2                    Afghanistan         NaN
# 3     Africa Western and Central         NaN
# 4                         Angola         NaN
# ..                           ...         ...
# 260                       Kosovo         NaN
# 261                  Yemen, Rep.         NaN
# 262                 South Africa         NaN
# 263                       Zambia         NaN
# 264                     Zimbabwe         NaN
#
# [265 rows x 71 columns]

# %%
len(dataset)
# Out:
# 265

# %%
dataset.shape
# Out:
# (265, 71)

# %%
#Population in the year 2020
dataset.groupby('Region').sum()['2020'].plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
#income category
dataset.groupby('IncomeGroup').sum()['2020'].plot.bar()
# Out:
# <AxesSubplot:xlabel='IncomeGroup'>

# %%
spi = pd.read_csv('API_IQ.SPI.OVRL_DS2_en_csv_v2_3186678.csv', skiprows=4)

# %%
gdp= pd.read_csv('API_NY.GDP.PCAP.CD_DS2_en_csv_v2_3159040.csv',  skiprows=4)

# %%
meta = pd.read_csv('Metadata_Country_API_IQ.SPI.OVRL_DS2_en_csv_v2_3186678.csv')

# %%
spi.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name Indicator Code  1960  \
# 0  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
# 1  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
# 2  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
# 3  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
# 4  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
#
#    1961  1962  1963  1964  1965  ...  2012  2013  2014  2015       2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN        NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN  37.222917
# 3   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN        NaN
# 4   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN  43.735417
#
#         2017       2018       2019  2020  Unnamed: 65
# 0        NaN        NaN        NaN   NaN          NaN
# 1        NaN        NaN        NaN   NaN          NaN
# 2  42.577917  49.845000  49.756250   NaN          NaN
# 3        NaN        NaN        NaN   NaN          NaN
# 4  46.689583  55.232083  54.945833   NaN          NaN
#
# [5 rows x 66 columns]

# %%
gdp.head()
# Out:
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  GDP per capita (current US$)
# 1  Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                  Afghanistan          AFG  GDP per capita (current US$)
# 3   Africa Western and Central          AFW  GDP per capita (current US$)
# 4                       Angola          AGO  GDP per capita (current US$)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
# 1  NY.GDP.PCAP.CD  147.836769  147.238537  156.426780  182.521139  162.594548
# 2  NY.GDP.PCAP.CD   59.773234   59.860900   58.458009   78.706429   82.095307
# 3  NY.GDP.PCAP.CD  107.963779  113.114697  118.865837  123.478967  131.892939
# 4  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
#
#          1965  ...          2012          2013          2014          2015  \
# 0         NaN  ...  24712.493263  26441.619936  26893.011506  28396.908423
# 1  180.489043  ...   1672.363658   1653.188436   1658.650062   1507.800256
# 2  101.108325  ...    641.871438    637.165464    613.856505    578.466353
# 3  138.566819  ...   1936.390962   2123.392433   2166.743309   1886.248158
# 4         NaN  ...   5100.097027   5254.881126   5408.411700   4166.979833
#
#            2016          2017          2018         2019         2020  \
# 0  28452.170615  29350.805019  30253.279358          NaN          NaN
# 1   1404.953164   1540.232473   1534.171767  1485.307425  1330.140232
# 2    509.220100    519.888913    493.756581   507.103392   508.808409
# 3   1666.422406   1606.978332   1695.959215  1772.339155  1714.426800
# 4   3506.073128   4095.810057   3289.643995  2809.626088  1895.770869
#
#    Unnamed: 65
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 66 columns]

# %%
spi.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name Indicator Code  1960  \
# 0  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
# 1  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
# 2  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
# 3  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
# 4  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
#
#    1961  1962  1963  1964  1965  ...  2012  2013  2014  2015       2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN        NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN  37.222917
# 3   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN        NaN
# 4   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN  43.735417
#
#         2017       2018       2019  2020  Unnamed: 65
# 0        NaN        NaN        NaN   NaN          NaN
# 1        NaN        NaN        NaN   NaN          NaN
# 2  42.577917  49.845000  49.756250   NaN          NaN
# 3        NaN        NaN        NaN   NaN          NaN
# 4  46.689583  55.232083  54.945833   NaN          NaN
#
# [5 rows x 66 columns]

# %% [markdown]
#  Extract column

# %%
spi = spi[['Country Code', '2019']]
gdp = gdp[['Country Code', '2019']]
meta = meta[['Country Code', 'Region']]

# %% [markdown]
# check null values

# %%
len(spi), len(spi.dropna())
# Out:
# (266, 174)

# %%
len(gdp), len(gdp.dropna())
# Out:
# (266, 247)

# %% [markdown]
# drop rows

# %%
spi = spi.dropna()
gdp = gdp.dropna()

# %%
spi.head()
# Out:
#   Country Code       2019
# 2          AFG  49.756250
# 4          AGO  54.945833
# 5          ALB  75.382917
# 8          ARE  59.669167
# 9          ARG  64.595833

# %%
spi.head()
# Out:
#   Country Code       2019
# 2          AFG  49.756250
# 4          AGO  54.945833
# 5          ALB  75.382917
# 8          ARE  59.669167
# 9          ARG  64.595833

# %% [markdown]
# Rename columns

# %%
spi = spi.rename(columns={'2019': 'SPI'})
gdp = gdp.rename(columns={'2019': 'GDP per capita'})

# %%
spi
# Out:
#     Country Code        SPI
# 2            AFG  49.756250
# 4            AGO  54.945833
# 5            ALB  75.382917
# 8            ARE  59.669167
# 9            ARG  64.595833
# ..           ...        ...
# 260          WSM  57.047083
# 262          YEM  36.771250
# 263          ZAF  73.475000
# 264          ZMB  59.014167
# 265          ZWE  61.652500
#
# [174 rows x 2 columns]

# %%
gdp
# Out:
#     Country Code  GDP per capita
# 1            AFE     1485.307425
# 2            AFG      507.103392
# 3            AFW     1772.339155
# 4            AGO     2809.626088
# 5            ALB     5355.847795
# ..           ...             ...
# 260          WSM     4324.101774
# 261          XKX     4445.890702
# 263          ZAF     6001.401121
# 264          ZMB     1305.002214
# 265          ZWE     1156.154864
#
# [247 rows x 2 columns]

# %% [markdown]
# Merge data

# %%
dataset = spi.merge(gdp, how='inner', on='Country Code')
dataset = dataset.merge(meta, how='inner', on='Country Code')

# %%
dataset
# Out:
#     Country Code        SPI  GDP per capita                      Region
# 0            AFG  49.756250      507.103392                  South Asia
# 1            AGO  54.945833     2809.626088          Sub-Saharan Africa
# 2            ALB  75.382917     5355.847795       Europe & Central Asia
# 3            ARE  59.669167    43103.336293  Middle East & North Africa
# 4            ARG  64.595833     9912.281809   Latin America & Caribbean
# ..           ...        ...             ...                         ...
# 165          VUT  40.691667     3102.346790         East Asia & Pacific
# 166          WSM  57.047083     4324.101774         East Asia & Pacific
# 167          ZAF  73.475000     6001.401121          Sub-Saharan Africa
# 168          ZMB  59.014167     1305.002214          Sub-Saharan Africa
# 169          ZWE  61.652500     1156.154864          Sub-Saharan Africa
#
# [170 rows x 4 columns]

# %%
meta
# Out:
#     Country Code                      Region
# 0            ABW   Latin America & Caribbean
# 1            AFE                         NaN
# 2            AFG                  South Asia
# 3            AFW                         NaN
# 4            AGO          Sub-Saharan Africa
# ..           ...                         ...
# 260          XKX       Europe & Central Asia
# 261          YEM  Middle East & North Africa
# 262          ZAF          Sub-Saharan Africa
# 263          ZMB          Sub-Saharan Africa
# 264          ZWE          Sub-Saharan Africa
#
# [265 rows x 2 columns]

# %% [markdown]
# # visualize data

# %%
#Visualize regional SPI
dataset.groupby('Region').mean()['SPI'].plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
#: Scatter plot SPI and GDP
# Linear scale
dataset.plot.scatter(x='GDP per capita', y='SPI' ,logx=True) 
dataset.plot.scatter(x='GDP per capita', y='SPI')
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='SPI'>

# %%
#sort and make horizontal barplot
dataset.groupby('Region').mean()['SPI'].sort_values(ascending=False).plot.barh()
# Out:
# <AxesSubplot:ylabel='Region'>

# %%
colors = dataset['Region'].factorize()[0]

dataset.plot.scatter(x='GDP per capita', y="SPI", c=colors, logx=True, cmap='tab10', xlabel='GDP per capita')
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='SPI'>
