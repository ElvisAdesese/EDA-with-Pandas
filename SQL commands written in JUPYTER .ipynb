# %%
import psycopg2 
import pandas as pd

# %%
conn= psycopg2.connect('dbname=elvis user=postgres host=localhost password=stipulated port=5432')

# %%
conn
# Out:
# <connection object at 0x000001E6430F1590; dsn: 'user=postgres password=xxx dbname=elvis host=localhost port=5432', closed: 0>

# %%
cur=conn.cursor()

# %%
cur
# Out:
# <cursor object at 0x000001E643115200; closed: 0>

# %% [markdown]
# # SELECTING ALL TABLES

# %%
cur.execute('SELECT * FROM person')

# %%
cur.fetchall()
# Out:
# [(1, 'Chris', 'Sam', 'MALE', datetime.date(1999, 1, 8), 'chrissam@yahoo.com'),
#  (2, 'Mike', 'Clem', 'MALE', datetime.date(1980, 4, 1), 'mikeclem@gmail.com'),
#  (3, 'Lucy', 'Lee', 'FEMALE', datetime.date(1970, 2, 5), None)]

# %%
cur.execute('SELECT * FROM person')

# %%
cur.fetchall()
# Out:
# [('9278fba4-609d-4961-94b1-538376a7880c',
#   'Teju',
#   'Lekan',
#   'lekanteju@gmail.com',
#   datetime.date(1990, 1, 9),
#   'Nigeria',
#   '9857aa4a-6927-4285-82d7-45037dd053e7'),
#  ('4506d922-07f0-455e-a470-884b3334469a',
#   'Ben',
#   'Fred',
#   'benfred@yahoo.com',
#   datetime.date(1997, 3, 1),
#   'Niger',
#   '3e8388a0-ec03-49fc-94f7-8bce1fdeb8e5'),
#  ('f3ef8a00-4ceb-477f-aa31-388cbea1073b',
#   'Ladi',
#   'Magu',
#   None,
#   datetime.date(1999, 6, 7),
#   'Nigeria',
#   'd46bf2bb-3f9c-42e3-99d1-bf805c0907af')]

# %% [markdown]
# # Creating a Table

# %% [raw]
# elvis=# INSERT INTO person(first_name, last_name, gender, date_of_birth, email)
# elvis-# VALUES('Chris', 'Sam', 'MALE', date '1999-01-08', 'chrissam@yahoo.com');
# INSERT 0 1
#
# elvis=# INSERT INTO person(first_name, last_name, gender, date_of_birth, email)
# elvis-# VALUES('Mike', 'Clem', 'MALE', date '1980-04-01', 'mikeclem@gmail.com');
# INSERT 0 1
#
# elvis=# INSERT INTO person(first_name, last_name, gender, date_of_birth)
# elvis-# VALUES('Lucy', 'Lee', 'FEMALE', date '1970-02-05');
# INSERT 0 1

# %% [markdown]
# # THE BASIC READ OPERATORS

# %%
cur.execute('SELECT * FROM mock_data')

# %%
cur.fetchall()
# Out:
# [(1,
#   'Sascha',
#   'Jekel',
#   'sjekel0@delicious.com',
#   'Female',
#   datetime.date(1974, 10, 29),
#   'Poland'),
#  (2,
#   'Drusy',
#   'Doe',
#   'ddoe1@geocities.com',
#   'Female',
#   datetime.date(1988, 12, 12),
#   'Philippines'),
#  (3,
#   'Kitti',
#   'Corderoy',
#   'kcorderoy2@cnet.com',
#   'Bigender',
#   datetime.date(2001, 11, 30),
#   'Indonesia'),
#  (4,
#   'Renata',
#   'Bauldrey',
#   'rbauldrey3@ning.com',
#   'Female',
#   datetime.date(1989, 9, 23),
#   'Sweden'),
#  (5,
#   'Jim',
#   'Cranson',
#   'jcranson4@examiner.com',
#   'Male',
#   datetime.date(1978, 11, 8),
#   'Brazil'),
#  (6,
#   'Concordia',
#   'Sharpin',
#   'csharpin5@yolasite.com',
#   'Female',
#   datetime.date(1979, 1, 24),
#   'Niger'),
#  (7,
#   'Richardo',
#   'Covotti',
#   'rcovotti6@nyu.edu',
#   'Male',
#   datetime.date(1986, 1, 18),
#   'Ethiopia'),
#  (8,
#   'Donna',
#   'Pattemore',
#   'dpattemore7@imgur.com',
#   'Female',
#   datetime.date(2010, 2, 12),
# ...

# %%
cur.execute('SELECT first_name, last_name FROM mock_data')

# %%
cur.fetchall()
# Out:
# [('Sascha', 'Jekel'),
#  ('Drusy', 'Doe'),
#  ('Kitti', 'Corderoy'),
#  ('Renata', 'Bauldrey'),
#  ('Jim', 'Cranson'),
#  ('Concordia', 'Sharpin'),
#  ('Richardo', 'Covotti'),
#  ('Donna', 'Pattemore'),
#  ('Salvidor', 'Philbrook'),
#  ('Matthieu', 'Piell'),
#  ('Cherice', 'Ghelardi'),
#  ('Teena', 'Joskowitz'),
#  ('Joey', 'Infantino'),
#  ('Boniface', 'Mussalli'),
#  ('Timmi', 'Colicot'),
#  ('Jewell', 'Furminger'),
#  ('Chelsae', 'Frears'),
#  ('Wally', 'Dorian'),
#  ('Galvin', 'Culwen'),
#  ('Matthiew', 'Etoile'),
#  ('Raynell', 'Bagnold'),
#  ('Rockey', 'Godbehere'),
#  ('Fredericka', 'Sheasby'),
#  ('Donny', 'Parsell'),
#  ('Ryun', 'Bison'),
#  ('Vanda', "O'Finan"),
#  ('Peri', 'Milmith'),
#  ('Randie', 'Stede'),
#  ('Carlo', 'Kornyakov'),
#  ('Essy', 'Giacoboni'),
#  ('Sergent', 'McNabb'),
#  ('Christal', 'Gercken'),
#  ('Mirabella', 'Aitken'),
#  ('Shaylah', 'Courtman'),
#  ('Sax', 'Yurivtsev'),
#  ('Maurizio', 'Gimson'),
#  ('Raviv', 'Lidyard'),
#  ('Betteanne', 'Shepley'),
# ...

# %% [markdown]
# # Sorting data by the ORDER BY KEY WORD (ASC AND DESC)

# %%
cur.execute('SELECT * FROM mock_data ORDER BY country_of_birth ASC')

# %%
cur.fetchall()
# Out:
# [(88,
#   'Justinn',
#   'Smalecombe',
#   'jsmalecombe2j@photobucket.com',
#   'Female',
#   datetime.date(2002, 4, 3),
#   'Afghanistan'),
#  (48,
#   'Roxi',
#   'Ludvigsen',
#   'rludvigsen1f@salon.com',
#   'Female',
#   datetime.date(1984, 10, 7),
#   'Australia'),
#  (23,
#   'Fredericka',
#   'Sheasby',
#   'fsheasbym@ucla.edu',
#   'Female',
#   datetime.date(2000, 11, 4),
#   'Brazil'),
#  (5,
#   'Jim',
#   'Cranson',
#   'jcranson4@examiner.com',
#   'Male',
#   datetime.date(1978, 11, 8),
#   'Brazil'),
#  (29,
#   'Carlo',
#   'Kornyakov',
#   'ckornyakovs@icio.us',
#   'Male',
#   datetime.date(1997, 5, 10),
#   'Cameroon'),
#  (9,
#   'Salvidor',
#   'Philbrook',
#   'sphilbrook8@globo.com',
#   'Male',
#   datetime.date(1976, 3, 5),
#   'Canada'),
#  (28,
#   'Randie',
#   'Stede',
#   'rsteder@ow.ly',
#   'Male',
#   datetime.date(1971, 9, 16),
#   'Canada'),
#  (46,
#   'Virginia',
#   'Plumbley',
#   'vplumbley1c@unesco.org',
#   'Female',
# ...

# %%
cur.execute('SELECT * FROM mock_data ORDER BY country_of_birth DESC')

# %%
cur.fetchall()
# Out:
# [(12,
#   'Teena',
#   'Joskowitz',
#   'tjoskowitzb@deviantart.com',
#   'Female',
#   datetime.date(2005, 8, 23),
#   'Vietnam'),
#  (69,
#   'Donaugh',
#   'Caldecutt',
#   'dcaldecutt20@histats.com',
#   'Male',
#   datetime.date(1993, 2, 16),
#   'Vietnam'),
#  (78,
#   'Cristy',
#   'Keneforde',
#   'ckeneforde29@ow.ly',
#   'Female',
#   datetime.date(1987, 1, 12),
#   'United States'),
#  (57,
#   'Ossie',
#   'Gonzalvo',
#   'ogonzalvo1o@cargocollective.com',
#   'Male',
#   datetime.date(2002, 12, 15),
#   'Ukraine'),
#  (27,
#   'Peri',
#   'Milmith',
#   'pmilmithq@usa.gov',
#   'Female',
#   datetime.date(2020, 3, 28),
#   'Thailand'),
#  (60,
#   'Carma',
#   'Andriolli',
#   'candriolli1r@abc.net.au',
#   'Female',
#   datetime.date(1973, 1, 28),
#   'Sweden'),
#  (4,
#   'Renata',
#   'Bauldrey',
#   'rbauldrey3@ning.com',
#   'Female',
#   datetime.date(1989, 9, 23),
#   'Sweden'),
#  (66,
#   'Dun',
#   'Maurice',
#   'dmaurice1x@w3.org',
#   'Male',
# ...

# %%
cur.execute('SELECT * FROM mock_data ORDER BY first_name DESC')

# %%
cur.fetchall()
# Out:
# [(47,
#   'Wenona',
#   'Margrett',
#   'wmargrett1e@rediff.com',
#   'Female',
#   datetime.date(1986, 2, 5),
#   'Indonesia'),
#  (18,
#   'Wally',
#   'Dorian',
#   'wdorianh@mayoclinic.com',
#   'Female',
#   datetime.date(1993, 1, 1),
#   'Guam'),
#  (46,
#   'Virginia',
#   'Plumbley',
#   'vplumbley1c@unesco.org',
#   'Female',
#   datetime.date(2003, 10, 18),
#   'Cape Verde'),
#  (26,
#   'Vanda',
#   "O'Finan",
#   'vofinanp@csmonitor.com',
#   'Female',
#   datetime.date(1973, 12, 4),
#   'China'),
#  (15,
#   'Timmi',
#   'Colicot',
#   'tcolicote@csmonitor.com',
#   'Female',
#   datetime.date(2013, 11, 8),
#   'France'),
#  (87,
#   'Tiffie',
#   'Shawl',
#   'tshawl2i@alibaba.com',
#   'Female',
#   datetime.date(2011, 8, 31),
#   'Guatemala'),
#  (12,
#   'Teena',
#   'Joskowitz',
#   'tjoskowitzb@deviantart.com',
#   'Female',
#   datetime.date(2005, 8, 23),
#   'Vietnam'),
#  (56,
#   'Tatum',
#   'Crallan',
#   'tcrallan1n@ning.com',
#   'Female',
# ...

# %% [markdown]
# # Sorting data by the DISTINCT KEY WORD

# %%
cur.execute('SELECT DISTINCT country_of_birth FROM mock_data ORDER BY country_of_birth DESC')
#USED TO REMOVE DUPLICATE RESULT FROM YOUR QUERY

# %%
cur.fetchall()
# Out:
# [('Vietnam',),
#  ('United States',),
#  ('Ukraine',),
#  ('Thailand',),
#  ('Sweden',),
#  ('Serbia',),
#  ('Russia',),
#  ('Portugal',),
#  ('Poland',),
#  ('Philippines',),
#  ('Peru',),
#  ('Niger',),
#  ('Mexico',),
#  ('Macedonia',),
#  ('Libya',),
#  ('Isle of Man',),
#  ('Ireland',),
#  ('Iraq',),
#  ('Iran',),
#  ('Indonesia',),
#  ('Guatemala',),
#  ('Guam',),
#  ('Gambia',),
#  ('France',),
#  ('Ethiopia',),
#  ('Dominican Republic',),
#  ('Colombia',),
#  ('China',),
#  ('Cape Verde',),
#  ('Canada',),
#  ('Cameroon',),
#  ('Brazil',),
#  ('Australia',),
#  ('Afghanistan',)]

# %% [markdown]
# # Sorting data by the WHERE CLAUSE, OR & AND KEY WORD

# %% [raw]
# elvis=# SELECT * from mock_data WHERE gender = 'Female';

# %% [raw]
# THE OUTPUT
# id | first_name | last_name  |             email             | gender | date_of_birth |  country_of_birth
# ----+------------+------------+-------------------------------+--------+---------------+--------------------
#   1 | Sascha     | Jekel      | sjekel0@delicious.com         | Female | 1974-10-29    | Poland
#   2 | Drusy      | Doe        | ddoe1@geocities.com           | Female | 1988-12-12    | Philippines
#   4 | Renata     | Bauldrey   | rbauldrey3@ning.com           | Female | 1989-09-23    | Sweden
#   6 | Concordia  | Sharpin    | csharpin5@yolasite.com        | Female | 1979-01-24    | Niger
#   8 | Donna      | Pattemore  | dpattemore7@imgur.com         | Female | 2010-02-12    | Isle of Man
#  11 | Cherice    | Ghelardi   | cghelardia@icq.com            | Female | 2004-11-23    | France
#  12 | Teena      | Joskowitz  | tjoskowitzb@deviantart.com    | Female | 2005-08-23    | Vietnam
#  15 | Timmi      | Colicot    | tcolicote@csmonitor.com       | Female | 2013-11-08    | France
#  16 | Jewell     | Furminger  | jfurmingerf@rakuten.co.jp     | Female | 1994-11-17    | France
#  17 | Chelsae    | Frears     | cfrearsg@meetup.com           | Female | 1980-07-16    | China
#  18 | Wally      | Dorian     | wdorianh@mayoclinic.com       | Female | 1993-01-01    | Guam
#  21 | Raynell    | Bagnold    | rbagnoldk@woothemes.com       | Female | 1993-12-09    | China
#  23 | Fredericka | Sheasby    | fsheasbym@ucla.edu            | Female | 2000-11-04    | Brazil
#  24 | Donny      | Parsell    | dparselln@jalbum.net          | Female | 1995-05-25    | Gambia
#  26 | Vanda      | O'Finan    | vofinanp@csmonitor.com        | Female | 1973-12-04    | China
#  27 | Peri       | Milmith    | pmilmithq@usa.gov             | Female | 2020-03-28    | Thailand
#  32 | Christal   | Gercken    | cgerckenw@intel.com           | Female | 1980-01-01    | Niger
#  33 | Mirabella  | Aitken     | maitkenx@unblog.fr            | Female | 1996-01-14    | Philippines
#  34 | Shaylah    | Courtman   | scourtmany@xinhuanet.com      | Female | 2016-10-10    | China
#  38 | Betteanne  | Shepley    | bshepley14@myspace.com        | Female | 2010-02-05    | France
#  39 | Sioux      | Wasson     | swasson15@hibu.com            | Female | 1999-02-17    | Macedonia
#  44 | Rowena     | Grimsdike  | rgrimsdike1a@accuweather.com  | Female | 2007-08-28    | Libya
#  46 | Virginia   | Plumbley   | vplumbley1c@unesco.org        | Female | 2003-10-18    | Cape Verde
#  47 | Wenona     | Margrett   | wmargrett1e@rediff.com        | Female | 1986-02-05    | Indonesia
#  48 | Roxi       | Ludvigsen  | rludvigsen1f@salon.com        | Female | 1984-10-07    | Australia
#  49 | Petunia    | Lummus     | plummus1g@cnet.com            | Female | 2020-04-13    | Portugal
#  53 | Alla       | Fazzioli   | afazzioli1k@cornell.edu       | Female | 2009-09-04    | Russia
#  55 | Moira      | Baugh      | mbaugh1m@bluehost.com         | Female | 2010-02-26    | Poland
#  56 | Tatum      | Crallan    | tcrallan1n@ning.com           | Female | 1994-03-14    | Ireland
#  59 | Audrey     | Bergeau    | abergeau1q@dagondesign.com    | Female | 1970-07-01    | Indonesia
#  60 | Carma      | Andriolli  | candriolli1r@abc.net.au       | Female | 1973-01-28    | Sweden
#  61 | Alidia     | Burkinshaw | aburkinshaw1s@technorati.com  | Female | 1980-05-17    | France
#  64 | Jenica     | Brownsill  | jbrownsill1v@ovh.net          | Female | 1978-01-11    | Portugal
#  65 | Bobbette   | Genders    | bgenders1w@newsvine.com       | Female | 2007-01-24    | Indonesia
#  67 | Camel      | Fulleylove | cfulleylove1y@bloglovin.com   | Female | 1981-06-29    | China
#  72 | Clara      | Crossgrove | ccrossgrove23@microsoft.com   | Female | 2012-04-18    | Philippines
#  75 | Clem       | Rozalski   | crozalski26@unesco.org        | Female | 1980-06-13    | China
#  78 | Cristy     | Keneforde  | ckeneforde29@ow.ly            | Female | 1987-01-12    | United States
#  80 | Melinde    | Kitcatt    | mkitcatt2b@blinklist.com      | Female | 1972-12-27    | China
#  81 | Annmaria   | Bastard    | abastard2c@ask.com            | Female | 1989-08-04    | Dominican Republic
#  82 | Ofilia     | Brigden    | obrigden2d@weebly.com         | Female | 2021-10-22    | Serbia
# -- More  --

# %% [raw]
# elvis=# SELECT * from mock_data WHERE gender = 'Female' AND country_of_birth = 'China';

# %% [raw]
# THE OUTPUT
#  id | first_name | last_name  |            email            | gender | date_of_birth | country_of_birth
# ----+------------+------------+-----------------------------+--------+---------------+------------------
#  17 | Chelsae    | Frears     | cfrearsg@meetup.com         | Female | 1980-07-16    | China
#  21 | Raynell    | Bagnold    | rbagnoldk@woothemes.com     | Female | 1993-12-09    | China
#  26 | Vanda      | O'Finan    | vofinanp@csmonitor.com      | Female | 1973-12-04    | China
#  34 | Shaylah    | Courtman   | scourtmany@xinhuanet.com    | Female | 2016-10-10    | China
#  67 | Camel      | Fulleylove | cfulleylove1y@bloglovin.com | Female | 1981-06-29    | China
#  75 | Clem       | Rozalski   | crozalski26@unesco.org      | Female | 1980-06-13    | China
#  80 | Melinde    | Kitcatt    | mkitcatt2b@blinklist.com    | Female | 1972-12-27    | China
#  84 | Bambie     | Cordet     | bcordet2f@alibaba.com       | Female | 2008-01-04    | China
#  89 | Cinnamon   | Abby       | cabby2k@studiopress.com     | Female | 2014-09-01    | China

# %% [raw]
# elvis=# SELECT * from mock_data WHERE gender = 'Female' AND (country_of_birth = 'China' OR country_of_birth ='Serbia');

# %% [raw]
#  id | first_name | last_name  |            email            | gender | date_of_birth | country_of_birth
# ----+------------+------------+-----------------------------+--------+---------------+------------------
#  17 | Chelsae    | Frears     | cfrearsg@meetup.com         | Female | 1980-07-16    | China
#  21 | Raynell    | Bagnold    | rbagnoldk@woothemes.com     | Female | 1993-12-09    | China
#  26 | Vanda      | O'Finan    | vofinanp@csmonitor.com      | Female | 1973-12-04    | China
#  34 | Shaylah    | Courtman   | scourtmany@xinhuanet.com    | Female | 2016-10-10    | China
#  67 | Camel      | Fulleylove | cfulleylove1y@bloglovin.com | Female | 1981-06-29    | China
#  75 | Clem       | Rozalski   | crozalski26@unesco.org      | Female | 1980-06-13    | China
#  80 | Melinde    | Kitcatt    | mkitcatt2b@blinklist.com    | Female | 1972-12-27    | China
#  82 | Ofilia     | Brigden    | obrigden2d@weebly.com       | Female | 2021-10-22    | Serbia
#  84 | Bambie     | Cordet     | bcordet2f@alibaba.com       | Female | 2008-01-04    | China
#  89 | Cinnamon   | Abby       | cabby2k@studiopress.com     | Female | 2014-09-01    | China

# %% [markdown]
# # Sorting data by the iLIKE AND LIKE KEYWORD (WILDCARD %)

# %% [raw]
# SELECT * FROM mock_data WHERE email LIKE '%.com';

# %% [raw]
# The Out Put
#  id | first_name | last_name  |              email              |   gender   | date_of_birth |  country_of_birth
# ----+------------+------------+---------------------------------+------------+---------------+--------------------
#   1 | Sascha     | Jekel      | sjekel0@delicious.com           | Female     | 1974-10-29    | Poland
#   2 | Drusy      | Doe        | ddoe1@geocities.com             | Female     | 1988-12-12    | Philippines
#   3 | Kitti      | Corderoy   | kcorderoy2@cnet.com             | Bigender   | 2001-11-30    | Indonesia
#   4 | Renata     | Bauldrey   | rbauldrey3@ning.com             | Female     | 1989-09-23    | Sweden
#   5 | Jim        | Cranson    | jcranson4@examiner.com          | Male       | 1978-11-08    | Brazil
#   6 | Concordia  | Sharpin    | csharpin5@yolasite.com          | Female     | 1979-01-24    | Niger
#   8 | Donna      | Pattemore  | dpattemore7@imgur.com           | Female     | 2010-02-12    | Isle of Man
#   9 | Salvidor   | Philbrook  | sphilbrook8@globo.com           | Male       | 1976-03-05    | Canada
#  11 | Cherice    | Ghelardi   | cghelardia@icq.com              | Female     | 2004-11-23    | France
#  12 | Teena      | Joskowitz  | tjoskowitzb@deviantart.com      | Female     | 2005-08-23    | Vietnam
#  13 | Joey       | Infantino  | jinfantinoc@usatoday.com        | Bigender   | 1995-06-23    | Philippines
#  14 | Boniface   | Mussalli   | bmussallid@businessweek.com     | Male       | 1994-02-24    | Russia
#  15 | Timmi      | Colicot    | tcolicote@csmonitor.com         | Female     | 2013-11-08    | France
#  17 | Chelsae    | Frears     | cfrearsg@meetup.com             | Female     | 1980-07-16    | China
#  18 | Wally      | Dorian     | wdorianh@mayoclinic.com         | Female     | 1993-01-01    | Guam
#  19 | Galvin     | Culwen     | gculweni@chron.com              | Male       | 1974-06-23    | Mexico
#  20 | Matthiew   | Etoile     | metoilej@forbes.com             | Male       | 2004-08-12    | Russia
#  21 | Raynell    | Bagnold    | rbagnoldk@woothemes.com         | Female     | 1993-12-09    | China
#  26 | Vanda      | O'Finan    | vofinanp@csmonitor.com          | Female     | 1973-12-04    | China
#  31 | Sergent    | McNabb     | smcnabbu@foxnews.com            | Male       | 2007-07-01    | China
#  32 | Christal   | Gercken    | cgerckenw@intel.com             | Female     | 1980-01-01    | Niger
#  34 | Shaylah    | Courtman   | scourtmany@xinhuanet.com        | Female     | 2016-10-10    | China
#  37 | Raviv      | Lidyard    | rlidyard13@booking.com          | Male       | 2002-07-27    | Poland
#  38 | Betteanne  | Shepley    | bshepley14@myspace.com          | Female     | 2010-02-05    | France
#  39 | Sioux      | Wasson     | swasson15@hibu.com              | Female     | 1999-02-17    | Macedonia
#  40 | Pall       | Sainz      | psainz16@jiathis.com            | Male       | 2002-05-22    | China
#  42 | Davey      | Stenet     | dstenet18@cnn.com               | Male       | 1982-06-23    | China
#  43 | Jorgan     | Enrique    | jenrique19@gizmodo.com          | Male       | 2021-08-04    | France
#  44 | Rowena     | Grimsdike  | rgrimsdike1a@accuweather.com    | Female     | 2007-08-28    | Libya
#  45 | Sammy      | Baert      | sbaert1b@reference.com          | Male       | 1994-05-07    | China
#  47 | Wenona     | Margrett   | wmargrett1e@rediff.com          | Female     | 1986-02-05    | Indonesia
#  48 | Roxi       | Ludvigsen  | rludvigsen1f@salon.com          | Female     | 1984-10-07    | Australia
#  49 | Petunia    | Lummus     | plummus1g@cnet.com              | Female     | 2020-04-13    | Portugal
#  50 | Flint      | Zuanazzi   | fzuanazzi1h@netscape.com        | Bigender   | 1998-01-11    | China
#  55 | Moira      | Baugh      | mbaugh1m@bluehost.com           | Female     | 2010-02-26    | Poland
#  56 | Tatum      | Crallan    | tcrallan1n@ning.com             | Female     | 1994-03-14    | Ireland
#  57 | Ossie      | Gonzalvo   | ogonzalvo1o@cargocollective.com | Male       | 2002-12-15    | Ukraine
#  59 | Audrey     | Bergeau    | abergeau1q@dagondesign.com      | Female     | 1970-07-01    | Indonesia
#  61 | Alidia     | Burkinshaw | aburkinshaw1s@technorati.com    | Female     | 1980-05-17    | France
#  62 | Gilberto   | Giacubo    | ggiacubo1t@mozilla.com          | Male       | 2020-07-04    | China
#  63 | Clarine    | Mynott     | cmynott1u@friendfeed.com        | Bigender   | 2019-10-25    | China
# -- More  --

# %% [raw]
# elvis=# SELECT * FROM mock_data WHERE email LIKE '%@mozilla.com';
#
# OUT PUT
# id | first_name | last_name |         email          | gender | date_of_birth | country_of_birth
# ----+------------+-----------+------------------------+--------+---------------+------------------
#  62 | Gilberto   | Giacubo   | ggiacubo1t@mozilla.com | Male   | 2020-07-04    | China
# (1 row)

# %% [raw]
# elvis=# SELECT * FROM mock_data WHERE email LIKE '%@google.%';
#
# THE OUTPUT
#  id | first_name | last_name |          email           |  gender  | date_of_birth | country_of_birth
# ----+------------+-----------+--------------------------+----------+---------------+------------------
#  25 | Ryun       | Bison     | rbisono@google.com.br    | Male     | 1970-07-12    | China
#  30 | Essy       | Giacoboni | egiacobonit@google.co.jp | Bigender | 1987-09-28    | Poland
#  36 | Maurizio   | Gimson    | mgimson11@google.com.br  | Male     | 1974-07-05    | Russia
#  90 | Aggie      | Sive      | asive2l@google.com.hk    | Female   | 1970-07-13    | Sweden
# (4 rows)

# %% [raw]
# The ILIKE ignore the upper case and lower case RESTRICTIONS
# elvis=# SELECT * FROM mock_data WHERE country_of_birth ILIKE 'china';
#
# The OUTPUT
#
#  id | first_name | last_name  |              email              |  gender  | date_of_birth | country_of_birth
# ----+------------+------------+---------------------------------+----------+---------------+------------------
#  17 | Chelsae    | Frears     | cfrearsg@meetup.com             | Female   | 1980-07-16    | China
#  21 | Raynell    | Bagnold    | rbagnoldk@woothemes.com         | Female   | 1993-12-09    | China
#  25 | Ryun       | Bison      | rbisono@google.com.br           | Male     | 1970-07-12    | China
#  26 | Vanda      | O'Finan    | vofinanp@csmonitor.com          | Female   | 1973-12-04    | China
#  31 | Sergent    | McNabb     | smcnabbu@foxnews.com            | Male     | 2007-07-01    | China
#  34 | Shaylah    | Courtman   | scourtmany@xinhuanet.com        | Female   | 2016-10-10    | China
#  40 | Pall       | Sainz      | psainz16@jiathis.com            | Male     | 2002-05-22    | China
#  42 | Davey      | Stenet     | dstenet18@cnn.com               | Male     | 1982-06-23    | China
#  45 | Sammy      | Baert      | sbaert1b@reference.com          | Male     | 1994-05-07    | China
#  50 | Flint      | Zuanazzi   | fzuanazzi1h@netscape.com        | Bigender | 1998-01-11    | China
#  62 | Gilberto   | Giacubo    | ggiacubo1t@mozilla.com          | Male     | 2020-07-04    | China
#  63 | Clarine    | Mynott     | cmynott1u@friendfeed.com        | Bigender | 2019-10-25    | China
#  67 | Camel      | Fulleylove | cfulleylove1y@bloglovin.com     | Female   | 1981-06-29    | China
#  71 | Saundra    | Ivain      | sivain22@cloudflare.com         | Male     | 2007-10-24    | China
#  75 | Clem       | Rozalski   | crozalski26@unesco.org          | Female   | 1980-06-13    | China
#  77 | Rice       | Tregensoe  | rtregensoe28@chicagotribune.com | Male     | 1997-03-20    | China
#  80 | Melinde    | Kitcatt    | mkitcatt2b@blinklist.com        | Female   | 1972-12-27    | China
#  83 | Lucas      | Wolton     | lwolton2e@nyu.edu               | Bigender | 1992-12-20    | China
#  84 | Bambie     | Cordet     | bcordet2f@alibaba.com           | Female   | 2008-01-04    | China
#  89 | Cinnamon   | Abby       | cabby2k@studiopress.com         | Female   | 2014-09-01    | China
# (20 rows)

# %% [markdown]
# # Sorting data by the GROUP BY and COUNT KEY WORD

# %%
#THE GROUP BY AND COUNT KEY WORD ALOWS YOU TO PERFROM SOME LEVEL STATS ON YOUR DATA. Also note that the count keyword helps you 
#sum the total number of values in field. 
cur.execute('SELECT country_of_birth, COUNT(*) FROM mock_data GROUP BY country_of_birth ORDER BY country_of_birth ASC;')

# %%
cur.fetchall()
# Out:
# [('Afghanistan', 1),
#  ('Australia', 1),
#  ('Brazil', 2),
#  ('Cameroon', 1),
#  ('Canada', 2),
#  ('Cape Verde', 1),
#  ('China', 20),
#  ('Colombia', 1),
#  ('Dominican Republic', 1),
#  ('Ethiopia', 1),
#  ('France', 9),
#  ('Gambia', 1),
#  ('Guam', 1),
#  ('Guatemala', 1),
#  ('Indonesia', 6),
#  ('Iran', 1),
#  ('Iraq', 1),
#  ('Ireland', 1),
#  ('Isle of Man', 1),
#  ('Libya', 1),
#  ('Macedonia', 1),
#  ('Mexico', 3),
#  ('Niger', 2),
#  ('Peru', 1),
#  ('Philippines', 6),
#  ('Poland', 7),
#  ('Portugal', 3),
#  ('Russia', 9),
#  ('Serbia', 1),
#  ('Sweden', 4),
#  ('Thailand', 1),
#  ('Ukraine', 1),
#  ('United States', 1),
#  ('Vietnam', 2)]

# %% [markdown]
# # Sorting data by the GROUP BY, HAVING and COUNT KEY WORD

# %%
#AGGREGATION
cur.execute('SELECT country_of_birth, COUNT(*) FROM mock_data GROUP BY country_of_birth HAVING COUNT(*)>5 ORDER BY country_of_birth ASC;')

# %%
cur.fetchall()
# Out:
# [('China', 20),
#  ('France', 9),
#  ('Indonesia', 6),
#  ('Philippines', 6),
#  ('Poland', 7),
#  ('Russia', 9)]

# %%
cur.execute('SELECT country_of_birth, COUNT(*) FROM mock_data GROUP BY country_of_birth HAVING COUNT(*)>=10 ORDER BY country_of_birth ASC;')

# %%
cur.fetchall()
# Out:
# [('China', 20)]

# %%
cur.execute('SELECT country_of_birth, COUNT(*) FROM mock_data GROUP BY country_of_birth HAVING COUNT(*)<=10 ORDER BY country_of_birth ASC;')

# %%
cur.fetchall()
# Out:
# [('Afghanistan', 1),
#  ('Australia', 1),
#  ('Brazil', 2),
#  ('Cameroon', 1),
#  ('Canada', 2),
#  ('Cape Verde', 1),
#  ('Colombia', 1),
#  ('Dominican Republic', 1),
#  ('Ethiopia', 1),
#  ('France', 9),
#  ('Gambia', 1),
#  ('Guam', 1),
#  ('Guatemala', 1),
#  ('Indonesia', 6),
#  ('Iran', 1),
#  ('Iraq', 1),
#  ('Ireland', 1),
#  ('Isle of Man', 1),
#  ('Libya', 1),
#  ('Macedonia', 1),
#  ('Mexico', 3),
#  ('Niger', 2),
#  ('Peru', 1),
#  ('Philippines', 6),
#  ('Poland', 7),
#  ('Portugal', 3),
#  ('Russia', 9),
#  ('Serbia', 1),
#  ('Sweden', 4),
#  ('Thailand', 1),
#  ('Ukraine', 1),
#  ('United States', 1),
#  ('Vietnam', 2)]

# %% [markdown]
# # LIMIT, OFFSET AND FETCH

# %%
cur.execute('SELECT * FROM mock_data LIMIT 10')

# %%
cur.fetchall()
# Out:
# [(1,
#   'Sascha',
#   'Jekel',
#   'sjekel0@delicious.com',
#   'Female',
#   datetime.date(1974, 10, 29),
#   'Poland'),
#  (2,
#   'Drusy',
#   'Doe',
#   'ddoe1@geocities.com',
#   'Female',
#   datetime.date(1988, 12, 12),
#   'Philippines'),
#  (3,
#   'Kitti',
#   'Corderoy',
#   'kcorderoy2@cnet.com',
#   'Bigender',
#   datetime.date(2001, 11, 30),
#   'Indonesia'),
#  (4,
#   'Renata',
#   'Bauldrey',
#   'rbauldrey3@ning.com',
#   'Female',
#   datetime.date(1989, 9, 23),
#   'Sweden'),
#  (5,
#   'Jim',
#   'Cranson',
#   'jcranson4@examiner.com',
#   'Male',
#   datetime.date(1978, 11, 8),
#   'Brazil'),
#  (6,
#   'Concordia',
#   'Sharpin',
#   'csharpin5@yolasite.com',
#   'Female',
#   datetime.date(1979, 1, 24),
#   'Niger'),
#  (7,
#   'Richardo',
#   'Covotti',
#   'rcovotti6@nyu.edu',
#   'Male',
#   datetime.date(1986, 1, 18),
#   'Ethiopia'),
#  (8,
#   'Donna',
#   'Pattemore',
#   'dpattemore7@imgur.com',
#   'Female',
#   datetime.date(2010, 2, 12),
# ...

# %%
cur.execute('SELECT * FROM mock_data OFFSET 5 LIMIT 10  ')

# %%
cur.fetchall()
# Out:
# [(6,
#   'Concordia',
#   'Sharpin',
#   'csharpin5@yolasite.com',
#   'Female',
#   datetime.date(1979, 1, 24),
#   'Niger'),
#  (7,
#   'Richardo',
#   'Covotti',
#   'rcovotti6@nyu.edu',
#   'Male',
#   datetime.date(1986, 1, 18),
#   'Ethiopia'),
#  (8,
#   'Donna',
#   'Pattemore',
#   'dpattemore7@imgur.com',
#   'Female',
#   datetime.date(2010, 2, 12),
#   'Isle of Man'),
#  (9,
#   'Salvidor',
#   'Philbrook',
#   'sphilbrook8@globo.com',
#   'Male',
#   datetime.date(1976, 3, 5),
#   'Canada'),
#  (10,
#   'Matthieu',
#   'Piell',
#   'mpiell9@archive.org',
#   'Male',
#   datetime.date(2005, 3, 19),
#   'Portugal'),
#  (11,
#   'Cherice',
#   'Ghelardi',
#   'cghelardia@icq.com',
#   'Female',
#   datetime.date(2004, 11, 23),
#   'France'),
#  (12,
#   'Teena',
#   'Joskowitz',
#   'tjoskowitzb@deviantart.com',
#   'Female',
#   datetime.date(2005, 8, 23),
#   'Vietnam'),
#  (13,
#   'Joey',
#   'Infantino',
#   'jinfantinoc@usatoday.com',
#   'Bigender',
# ...

# %% [markdown]
# # Sorting data by the IN KEY WORD

# %% [raw]
# elvis=# SELECT * FROM mock_data WHERE country_of_birth IN ('Brazil', 'China', 'France');

# %% [raw]
# OUT PUT
#
# id | first_name | last_name  |              email              |   gender   | date_of_birth | country_of_birth
# ----+------------+------------+---------------------------------+------------+---------------+------------------
#   5 | Jim        | Cranson    | jcranson4@examiner.com          | Male       | 1978-11-08    | Brazil
#  11 | Cherice    | Ghelardi   | cghelardia@icq.com              | Female     | 2004-11-23    | France
#  15 | Timmi      | Colicot    | tcolicote@csmonitor.com         | Female     | 2013-11-08    | France
#  16 | Jewell     | Furminger  | jfurmingerf@rakuten.co.jp       | Female     | 1994-11-17    | France
#  17 | Chelsae    | Frears     | cfrearsg@meetup.com             | Female     | 1980-07-16    | China
#  21 | Raynell    | Bagnold    | rbagnoldk@woothemes.com         | Female     | 1993-12-09    | China
#  23 | Fredericka | Sheasby    | fsheasbym@ucla.edu              | Female     | 2000-11-04    | Brazil
#  25 | Ryun       | Bison      | rbisono@google.com.br           | Male       | 1970-07-12    | China
#  26 | Vanda      | O'Finan    | vofinanp@csmonitor.com          | Female     | 1973-12-04    | China
#  31 | Sergent    | McNabb     | smcnabbu@foxnews.com            | Male       | 2007-07-01    | China
#  34 | Shaylah    | Courtman   | scourtmany@xinhuanet.com        | Female     | 2016-10-10    | China
#  38 | Betteanne  | Shepley    | bshepley14@myspace.com          | Female     | 2010-02-05    | France
#  40 | Pall       | Sainz      | psainz16@jiathis.com            | Male       | 2002-05-22    | China
#  42 | Davey      | Stenet     | dstenet18@cnn.com               | Male       | 1982-06-23    | China
#  43 | Jorgan     | Enrique    | jenrique19@gizmodo.com          | Male       | 2021-08-04    | France
#  45 | Sammy      | Baert      | sbaert1b@reference.com          | Male       | 1994-05-07    | China
#  50 | Flint      | Zuanazzi   | fzuanazzi1h@netscape.com        | Bigender   | 1998-01-11    | China
#  61 | Alidia     | Burkinshaw | aburkinshaw1s@technorati.com    | Female     | 1980-05-17    | France
#  62 | Gilberto   | Giacubo    | ggiacubo1t@mozilla.com          | Male       | 2020-07-04    | China
#  63 | Clarine    | Mynott     | cmynott1u@friendfeed.com        | Bigender   | 2019-10-25    | China
#  67 | Camel      | Fulleylove | cfulleylove1y@bloglovin.com     | Female     | 1981-06-29    | China
#  68 | Base       | Hatley     | bhatley1z@yolasite.com          | Male       | 1997-01-31    | France
#  71 | Saundra    | Ivain      | sivain22@cloudflare.com         | Male       | 2007-10-24    | China
#  75 | Clem       | Rozalski   | crozalski26@unesco.org          | Female     | 1980-06-13    | China
#  77 | Rice       | Tregensoe  | rtregensoe28@chicagotribune.com | Male       | 1997-03-20    | China
#  80 | Melinde    | Kitcatt    | mkitcatt2b@blinklist.com        | Female     | 1972-12-27    | China
#  83 | Lucas      | Wolton     | lwolton2e@nyu.edu               | Bigender   | 1992-12-20    | China
# -- More  --

# %% [raw]
# elvis=# SELECT * FROM mock_data WHERE country_of_birth IN
# ('Brazil', 'China', 'France') ORDER BY country_of_birth LIMIT 10;
#
#
# OUTPUT
#
#  id | first_name | last_name |          email           | gender | date_of_birth | country_of_birth
# ----+------------+-----------+--------------------------+--------+---------------+------------------
#  23 | Fredericka | Sheasby   | fsheasbym@ucla.edu       | Female | 2000-11-04    | Brazil
#   5 | Jim        | Cranson   | jcranson4@examiner.com   | Male   | 1978-11-08    | Brazil
#  40 | Pall       | Sainz     | psainz16@jiathis.com     | Male   | 2002-05-22    | China
#  17 | Chelsae    | Frears    | cfrearsg@meetup.com      | Female | 1980-07-16    | China
#  21 | Raynell    | Bagnold   | rbagnoldk@woothemes.com  | Female | 1993-12-09    | China
#  25 | Ryun       | Bison     | rbisono@google.com.br    | Male   | 1970-07-12    | China
#  34 | Shaylah    | Courtman  | scourtmany@xinhuanet.com | Female | 2016-10-10    | China
#  26 | Vanda      | O'Finan   | vofinanp@csmonitor.com   | Female | 1973-12-04    | China
#  31 | Sergent    | McNabb    | smcnabbu@foxnews.com     | Male   | 2007-07-01    | China
#  42 | Davey      | Stenet    | dstenet18@cnn.com        | Male   | 1982-06-23    | China

# %% [markdown]
# # Sorting data by the BETWEEN KEY WORD

# %% [raw]
# elvis=# SELECT * FROM mock_data WHERE date_of_birth BETWEEN DATE '1982-06-23' AND '2000-11-04';

# %% [raw]
#  id | first_name | last_name |              email              |  gender  | date_of_birth |  country_of_birth
# ----+------------+-----------+---------------------------------+----------+---------------+--------------------
#   2 | Drusy      | Doe       | ddoe1@geocities.com             | Female   | 1988-12-12    | Philippines
#   4 | Renata     | Bauldrey  | rbauldrey3@ning.com             | Female   | 1989-09-23    | Sweden
#   7 | Richardo   | Covotti   | rcovotti6@nyu.edu               | Male     | 1986-01-18    | Ethiopia
#  13 | Joey       | Infantino | jinfantinoc@usatoday.com        | Bigender | 1995-06-23    | Philippines
#  14 | Boniface   | Mussalli  | bmussallid@businessweek.com     | Male     | 1994-02-24    | Russia
#  16 | Jewell     | Furminger | jfurmingerf@rakuten.co.jp       | Female   | 1994-11-17    | France
#  18 | Wally      | Dorian    | wdorianh@mayoclinic.com         | Female   | 1993-01-01    | Guam
#  21 | Raynell    | Bagnold   | rbagnoldk@woothemes.com         | Female   | 1993-12-09    | China
#  23 | Fredericka | Sheasby   | fsheasbym@ucla.edu              | Female   | 2000-11-04    | Brazil
#  24 | Donny      | Parsell   | dparselln@jalbum.net            | Female   | 1995-05-25    | Gambia
#  29 | Carlo      | Kornyakov | ckornyakovs@icio.us             | Male     | 1997-05-10    | Cameroon
#  30 | Essy       | Giacoboni | egiacobonit@google.co.jp        | Bigender | 1987-09-28    | Poland
#  33 | Mirabella  | Aitken    | maitkenx@unblog.fr              | Female   | 1996-01-14    | Philippines
#  39 | Sioux      | Wasson    | swasson15@hibu.com              | Female   | 1999-02-17    | Macedonia
#  41 | Bunni      | Flanner   | bflanner17@creativecommons.org  | Bigender | 1986-08-13    | Poland
#  42 | Davey      | Stenet    | dstenet18@cnn.com               | Male     | 1982-06-23    | China
#  45 | Sammy      | Baert     | sbaert1b@reference.com          | Male     | 1994-05-07    | China
#  47 | Wenona     | Margrett  | wmargrett1e@rediff.com          | Female   | 1986-02-05    | Indonesia
#  48 | Roxi       | Ludvigsen | rludvigsen1f@salon.com          | Female   | 1984-10-07    | Australia
#  50 | Flint      | Zuanazzi  | fzuanazzi1h@netscape.com        | Bigender | 1998-01-11    | China
#  56 | Tatum      | Crallan   | tcrallan1n@ning.com             | Female   | 1994-03-14    | Ireland
#  68 | Base       | Hatley    | bhatley1z@yolasite.com          | Male     | 1997-01-31    | France
#  69 | Donaugh    | Caldecutt | dcaldecutt20@histats.com        | Male     | 1993-02-16    | Vietnam
#  73 | Cobb       | Bourke    | cbourke24@sohu.com              | Male     | 1986-03-18    | Russia
#  77 | Rice       | Tregensoe | rtregensoe28@chicagotribune.com | Male     | 1997-03-20    | China
#  78 | Cristy     | Keneforde | ckeneforde29@ow.ly              | Female   | 1987-01-12    | United States
#  81 | Annmaria   | Bastard   | abastard2c@ask.com              | Female   | 1989-08-04    | Dominican Republic
#  83 | Lucas      | Wolton    | lwolton2e@nyu.edu               | Bigender | 1992-12-20    | China
#  86 | Shaughn    | Colquyte  | scolquyte2h@facebook.com        | Male     | 1983-02-15    | France
# (29 rows)

# %%
cur.execute('SELECT * FROM car')

# %%
cur.fetchall()
# Out:
# [(1, 'Ford', 'Thunderbird', '$6,907.17'),
#  (2, 'Volvo', 'C70', '$3,083.68'),
#  (3, 'BMW', '1 Series', '$6,707.11'),
#  (4, 'Lotus', 'Esprit', '$2,531.50'),
#  (5, 'Chevrolet', 'Avalanche 2500', '$8,266.11'),
#  (6, 'Lexus', 'LX', '$6,750.91'),
#  (7, 'Dodge', 'Journey', '$6,787.76'),
#  (8, 'Nissan', 'Armada', '$9,452.76'),
#  (9, 'Nissan', 'Altima', '$3,755.74'),
#  (10, 'Ford', 'Mustang', '$3,568.79'),
#  (11, 'Lincoln', 'Town Car', '$8,031.42'),
#  (12, 'Ford', 'Taurus', '$9,822.84'),
#  (13, 'Eagle', 'Premier', '$2,170.62'),
#  (14, 'Audi', 'S6', '$5,014.55'),
#  (15, 'Toyota', 'Tundra', '$3,071.99'),
#  (16, 'Plymouth', 'Prowler', '$8,722.17'),
#  (17, 'Buick', 'Century', '$7,252.88'),
#  (18, 'Chrysler', 'Concorde', '$8,101.23'),
#  (19, 'Ford', 'Freestar', '$7,684.56'),
#  (20, 'Pontiac', 'Montana', '$3,681.79'),
#  (21, 'Mazda', 'B-Series Plus', '$2,127.48'),
#  (22, 'Chevrolet', 'Monza', '$2,672.24'),
#  (23, 'Lexus', 'GS', '$2,645.26'),
# ...

# %% [markdown]
# # CALCULATING MAX, MIN AND AVERAGE

# %%
cur.execute('SELECT MAX(price) FROM car')

# %%
cur.fetchall()
# Out:
# [('$9,751.89',)]

# %%
cur.execute('SELECT MIN(price) FROM car')

# %%
cur.fetchall()
# Out:
# [('$1,114.58',)]

# %%
cur.execute('SELECT make, model, MIN(price) FROM car GROUP BY make, model')

# %%
cur.fetchall()
# Out:
# [('Volkswagen', 'Rabbit', '$5,782.99'),
#  ('Aptera', 'Typ-1', '$1,114.58'),
#  ('Kia', 'Amanti', '$4,974.47'),
#  ('Toyota', 'T100 Xtra', '$6,066.38'),
#  ('Saab', '9-3', '$9,066.64'),
#  ('Nissan', 'Pathfinder', '$6,998.13'),
#  ('Ferrari', '612 Scaglietti', '$3,806.21'),
#  ('Mercedes-Benz', 'SLK-Class', '$7,753.17'),
#  ('Mitsubishi', 'GTO', '$7,821.20'),
#  ('Mercury', 'Mountaineer', '$6,551.44'),
#  ('Audi', '100', '$8,230.05'),
#  ('Isuzu', 'Impulse', '$6,267.34'),
#  ('Acura', 'RL', '$9,329.44'),
#  ('Mitsubishi', 'Eclipse', '$7,099.16'),
#  ('Cadillac', 'CTS', '$8,044.51'),
#  ('Chrysler', 'Imperial', '$7,887.21'),
#  ('Land Rover', 'Discovery', '$1,952.33'),
#  ('Pontiac', 'Turbo Firefly', '$2,878.89'),
#  ('Dodge', 'Intrepid', '$7,092.99'),
#  ('Hyundai', 'Sonata', '$6,488.47'),
#  ('Audi', 'A8', '$8,039.40'),
#  ('Ford', 'Festiva', '$2,802.41'),
#  ('Jaguar', 'XJ', '$2,191.33'),
#  ('Dodge', 'Charger', '$4,851.07'),
#  ('Mazda', 'MX-6', '$8,207.61'),
# ...

# %%
cur.execute('SELECT make, model, Max(price) FROM car GROUP BY make, model')

# %%
cur.fetchall()
# Out:
# [('Volkswagen', 'Rabbit', '$5,782.99'),
#  ('Aptera', 'Typ-1', '$1,114.58'),
#  ('Kia', 'Amanti', '$4,974.47'),
#  ('Toyota', 'T100 Xtra', '$6,066.38'),
#  ('Saab', '9-3', '$9,066.64'),
#  ('Nissan', 'Pathfinder', '$6,998.13'),
#  ('Ferrari', '612 Scaglietti', '$3,806.21'),
#  ('Mercedes-Benz', 'SLK-Class', '$7,753.17'),
#  ('Mitsubishi', 'GTO', '$7,821.20'),
#  ('Mercury', 'Mountaineer', '$6,551.44'),
#  ('Audi', '100', '$8,230.05'),
#  ('Isuzu', 'Impulse', '$6,267.34'),
#  ('Acura', 'RL', '$9,329.44'),
#  ('Mitsubishi', 'Eclipse', '$7,099.16'),
#  ('Cadillac', 'CTS', '$8,044.51'),
#  ('Chrysler', 'Imperial', '$7,887.21'),
#  ('Land Rover', 'Discovery', '$1,952.33'),
#  ('Pontiac', 'Turbo Firefly', '$2,878.89'),
#  ('Dodge', 'Intrepid', '$7,092.99'),
#  ('Hyundai', 'Sonata', '$6,488.47'),
#  ('Audi', 'A8', '$8,039.40'),
#  ('Ford', 'Festiva', '$2,802.41'),
#  ('Jaguar', 'XJ', '$2,191.33'),
#  ('Dodge', 'Charger', '$4,851.07'),
#  ('Mazda', 'MX-6', '$8,207.61'),
# ...

# %%
cur.execute('SELECT SUM(price) FROM car')

# %%
cur.fetchall()
# Out:
# [('$627,755.96',)]

# %%
cur.execute('SELECT make, SUM(price) FROM car GROUP BY make')

# %%
cur.fetchall()
# Out:
# [('Honda', '$5,800.29'),
#  ('Ford', '$51,296.58'),
#  ('Scion', '$13,259.80'),
#  ('Aptera', '$1,114.58'),
#  ('Dodge', '$44,384.07'),
#  ('Maserati', '$8,747.08'),
#  ('Chevrolet', '$59,875.95'),
#  ('Bentley', '$17,587.30'),
#  ('Pontiac', '$28,317.25'),
#  ('Porsche', '$7,840.16'),
#  ('Audi', '$46,381.02'),
#  ('Jaguar', '$2,191.33'),
#  ('Lexus', '$13,853.63'),
#  ('Kia', '$10,974.74'),
#  ('Lamborghini', '$2,721.32'),
#  ('Mercedes-Benz', '$13,673.26'),
#  ('Land Rover', '$6,425.36'),
#  ('Volvo', '$20,095.97'),
#  ('Cadillac', '$18,351.25'),
#  ('Nissan', '$15,768.44'),
#  ('Acura', '$9,329.44'),
#  ('Saab', '$9,066.64'),
#  ('Suzuki', '$7,842.50'),
#  ('Hyundai', '$12,231.61'),
#  ('Mitsubishi', '$24,281.64'),
#  ('Subaru', '$16,194.48'),
#  ('Mazda', '$36,059.30'),
#  ('BMW', '$26,582.13'),
#  ('Volkswagen', '$5,782.99'),
#  ('Mercury', '$25,175.53'),
#  ('Eagle', '$3,979.79'),
#  ('Chrysler', '$7,887.21'),
#  ('Ferrari', '$3,806.21'),
#  ('Hummer', '$4,786.52'),
# ...

# %% [markdown]
# # Accessing Age Function in Postgres

# %%
cur.execute('SELECT first_name, last_name, gender, country_of_birth, date_of_birth, AGE(NOW(), date_of_birth) FROM mock_data')

# %%
cur.fetchall()
# Out:
# [('Sascha',
#   'Jekel',
#   'Female',
#   'Poland',
#   datetime.date(1974, 10, 29),
#   datetime.timedelta(days=17335, seconds=3948, microseconds=558903)),
#  ('Drusy',
#   'Doe',
#   'Female',
#   'Philippines',
#   datetime.date(1988, 12, 12),
#   datetime.timedelta(days=12181, seconds=3948, microseconds=558903)),
#  ('Kitti',
#   'Corderoy',
#   'Bigender',
#   'Indonesia',
#   datetime.date(2001, 11, 30),
#   datetime.timedelta(days=7448, seconds=3948, microseconds=558903)),
#  ('Renata',
#   'Bauldrey',
#   'Female',
#   'Sweden',
#   datetime.date(1989, 9, 23),
#   datetime.timedelta(days=11895, seconds=3948, microseconds=558903)),
#  ('Jim',
#   'Cranson',
#   'Male',
#   'Brazil',
#   datetime.date(1978, 11, 8),
#   datetime.timedelta(days=15865, seconds=3948, microseconds=558903)),
#  ('Concordia',
#   'Sharpin',
#   'Female',
#   'Niger',
#   datetime.date(1979, 1, 24),
#   datetime.timedelta(days=15789, seconds=3948, microseconds=558903)),
#  ('Richardo',
#   'Covotti',
# ...

# %% [raw]
# elvis=# SELECT first_name, last_name, gender, country_of_birth, date_of_birth, AGE(NOW(), date_of_birth) FROM mock_data;
#
# OutPut
# first_name  | last_name  |   gender   |  country_of_birth  | date_of_birth |                   age
# -------------+------------+------------+--------------------+---------------+-----------------------------------------
#  Sascha      | Jekel      | Female     | Poland             | 1974-10-29    | 47 years 5 mons 30 days 01:02:37.49692
#  Drusy       | Doe        | Female     | Philippines        | 1988-12-12    | 33 years 4 mons 16 days 01:02:37.49692
#  Kitti       | Corderoy   | Bigender   | Indonesia          | 2001-11-30    | 20 years 4 mons 28 days 01:02:37.49692
#  Renata      | Bauldrey   | Female     | Sweden             | 1989-09-23    | 32 years 7 mons 5 days 01:02:37.49692
#  Jim         | Cranson    | Male       | Brazil             | 1978-11-08    | 43 years 5 mons 20 days 01:02:37.49692
#  Concordia   | Sharpin    | Female     | Niger              | 1979-01-24    | 43 years 3 mons 4 days 01:02:37.49692
#  Richardo    | Covotti    | Male       | Ethiopia           | 1986-01-18    | 36 years 3 mons 10 days 01:02:37.49692
#  Donna       | Pattemore  | Female     | Isle of Man        | 2010-02-12    | 12 years 2 mons 16 days 01:02:37.49692
#  Salvidor    | Philbrook  | Male       | Canada             | 1976-03-05    | 46 years 1 mon 23 days 01:02:37.49692
#  Matthieu    | Piell      | Male       | Portugal           | 2005-03-19    | 17 years 1 mon 9 days 01:02:37.49692
#  Cherice     | Ghelardi   | Female     | France             | 2004-11-23    | 17 years 5 mons 5 days 01:02:37.49692
#  Teena       | Joskowitz  | Female     | Vietnam            | 2005-08-23    | 16 years 8 mons 5 days 01:02:37.49692
#  Joey        | Infantino  | Bigender   | Philippines        | 1995-06-23    | 26 years 10 mons 5 days 01:02:37.49692
#  Boniface    | Mussalli   | Male       | Russia             | 1994-02-24    | 28 years 2 mons 4 days 01:02:37.49692
#  Timmi       | Colicot    | Female     | France             | 2013-11-08    | 8 years 5 mons 20 days 01:02:37.49692
#  Jewell      | Furminger  | Female     | France             | 1994-11-17    | 27 years 5 mons 11 days 01:02:37.49692
#  Chelsae     | Frears     | Female     | China              | 1980-07-16    | 41 years 9 mons 12 days 01:02:37.49692
#  Wally       | Dorian     | Female     | Guam               | 1993-01-01    | 29 years 3 mons 27 days 01:02:37.49692
#  Galvin      | Culwen     | Male       | Mexico             | 1974-06-23    | 47 years 10 mons 5 days 01:02:37.49692
#  Matthiew    | Etoile     | Male       | Russia             | 2004-08-12    | 17 years 8 mons 16 days 01:02:37.49692
#  Raynell     | Bagnold    | Female     | China              | 1993-12-09    | 28 years 4 mons 19 days 01:02:37.49692
#  Rockey      | Godbehere  | Male       | Philippines        | 1981-01-07    | 41 years 3 mons 21 days 01:02:37.49692
#  Fredericka  | Sheasby    | Female     | Brazil             | 2000-11-04    | 21 years 5 mons 24 days 01:02:37.49692
#  Donny       | Parsell    | Female     | Gambia             | 1995-05-25    | 26 years 11 mons 3 days 01:02:37.49692
#  Ryun        | Bison      | Male       | China              | 1970-07-12    | 51 years 9 mons 16 days 01:02:37.49692
#  Vanda       | O'Finan    | Female     | China              | 1973-12-04    | 48 years 4 mons 24 days 01:02:37.49692
#  Peri        | Milmith    | Female     | Thailand           | 2020-03-28    | 2 years 1 mon 01:02:37.49692
#  Randie      | Stede      | Male       | Canada             | 1971-09-16    | 50 years 7 mons 12 days 01:02:37.49692
#  Carlo       | Kornyakov  | Male       | Cameroon           | 1997-05-10    | 24 years 11 mons 18 days 01:02:37.49692
#  Essy        | Giacoboni  | Bigender   | Poland             | 1987-09-28    | 34 years 7 mons 01:02:37.49692
#  Sergent     | McNabb     | Male       | China              | 2007-07-01    | 14 years 9 mons 27 days 01:02:37.49692
#  Christal    | Gercken    | Female     | Niger              | 1980-01-01    | 42 years 3 mons 27 days 01:02:37.49692
#  Mirabella   | Aitken     | Female     | Philippines        | 1996-01-14    | 26 years 3 mons 14 days 01:02:37.49692
#  Shaylah     | Courtman   | Female     | China              | 2016-10-10    | 5 years 6 mons 18 days 01:02:37.49692
#  Sax         | Yurivtsev  | Male       | Peru               | 2006-04-23    | 16 years 5 days 01:02:37.49692
#  Maurizio    | Gimson     | Male       | Russia             | 1974-07-05    | 47 years 9 mons 23 days 01:02:37.49692
#  Raviv       | Lidyard    | Male       | Poland             | 2002-07-27    | 19 years 9 mons 1 day 01:02:37.49692
#  Betteanne   | Shepley    | Female     | France             | 2010-02-05    | 12 years 2 mons 23 days 01:02:37.49692
#  Sioux       | Wasson     | Female     | Macedonia          | 1999-02-17    | 23 years 2 mons 11 days 01:02:37.49692
#  Pall        | Sainz      | Male       | China              | 2002-05-22    | 19 years 11 mons 6 days 01:02:37.49692
#  Bunni       | Flanner    | Bigender   | Poland             | 1986-08-13    | 35 years 8 mons 15 days 01:02:37.49692
# -- More  --

# %%
cur.execute('SELECT * FROM people')

# %%
cur.fetchall()
# Out:
# [(1,
#   'Rolando',
#   'Cowterd',
#   'Agender',
#   'rcowterd0@i2i.jp',
#   datetime.date(1989, 6, 20),
#   'Mauritius'),
#  (2,
#   'Carlin',
#   'Botright',
#   'Female',
#   None,
#   datetime.date(2017, 6, 14),
#   'Colombia'),
#  (3,
#   'Dwayne',
#   'Wellbank',
#   'Male',
#   None,
#   datetime.date(1974, 9, 26),
#   'Indonesia'),
#  (4,
#   'Clevey',
#   'Place',
#   'Male',
#   'cplace3@disqus.com',
#   datetime.date(1966, 1, 5),
#   'Russia'),
#  (5,
#   'Oren',
#   'Shrigley',
#   'Genderfluid',
#   None,
#   datetime.date(1964, 12, 12),
#   'Kazakhstan'),
#  (6,
#   'Evangeline',
#   'Windless',
#   'Genderfluid',
#   'ewindless5@exblog.jp',
#   datetime.date(1991, 3, 10),
#   'China'),
#  (7,
#   'Bathsheba',
#   'Glanz',
#   'Female',
#   'bglanz6@mysql.com',
#   datetime.date(1970, 9, 13),
#   'Ukraine'),
#  (8,
#   'Jody',
#   'Wolfers',
#   'Female',
#   'jwolfers7@purevolume.com',
#   datetime.date(1973, 12, 23),
#   'Brazil'),
#  (9,
#   'Glad',
#   'Skippen',
# ...

# %% [raw]
# elvis=# DELETE FROM people WHERE id = 99;
# DELETE 1
# elvis=# DELETE FROM people WHERE gender = 'Male';
# DELETE 44
# elvis=# UPDATE people SET first_name = 'Jerry', last_name = 'Wise Man', email = 'jerrywiseman@gmail.com' WHERE id = 98;
# UPDATE 1

# %%
cur.execute('SELECT * FROM person ')

# %%
cur.fetchall()
# Out:
# [('9278fba4-609d-4961-94b1-538376a7880c',
#   'Teju',
#   'Lekan',
#   'lekanteju@gmail.com',
#   datetime.date(1990, 1, 9),
#   'Nigeria',
#   '9857aa4a-6927-4285-82d7-45037dd053e7'),
#  ('4506d922-07f0-455e-a470-884b3334469a',
#   'Ben',
#   'Fred',
#   'benfred@yahoo.com',
#   datetime.date(1997, 3, 1),
#   'Niger',
#   '3e8388a0-ec03-49fc-94f7-8bce1fdeb8e5'),
#  ('f3ef8a00-4ceb-477f-aa31-388cbea1073b',
#   'Ladi',
#   'Magu',
#   None,
#   datetime.date(1999, 6, 7),
#   'Nigeria',
#   'd46bf2bb-3f9c-42e3-99d1-bf805c0907af')]

# %%
cur.execute('SELECT * FROM car')

# %%
cur.fetchall()
# Out:
# [('9857aa4a-6927-4285-82d7-45037dd053e7', 'Ford', 'High', '? 20,000.00'),
#  ('3e8388a0-ec03-49fc-94f7-8bce1fdeb8e5', 'Toyota', 'Camery', '? 80,000.00'),
#  ('d46bf2bb-3f9c-42e3-99d1-bf805c0907af', 'Toyota', 'Corolla', '? 72,000.00')]

# %% [markdown]
# # UUID AS PRIMARY INNER JOIN

# %%
cur.execute('SELECT * FROM person JOIN car USING (car_uid)')

# %%
cur.fetchall()
# Out:
# [('9857aa4a-6927-4285-82d7-45037dd053e7',
#   '9278fba4-609d-4961-94b1-538376a7880c',
#   'Teju',
#   'Lekan',
#   'lekanteju@gmail.com',
#   datetime.date(1990, 1, 9),
#   'Nigeria',
#   'Ford',
#   'High',
#   '? 20,000.00'),
#  ('3e8388a0-ec03-49fc-94f7-8bce1fdeb8e5',
#   '4506d922-07f0-455e-a470-884b3334469a',
#   'Ben',
#   'Fred',
#   'benfred@yahoo.com',
#   datetime.date(1997, 3, 1),
#   'Niger',
#   'Toyota',
#   'Camery',
#   '? 80,000.00'),
#  ('d46bf2bb-3f9c-42e3-99d1-bf805c0907af',
#   'f3ef8a00-4ceb-477f-aa31-388cbea1073b',
#   'Ladi',
#   'Magu',
#   None,
#   datetime.date(1999, 6, 7),
#   'Nigeria',
#   'Toyota',
#   'Corolla',
#   '? 72,000.00')]

# %%
cur.execute('SELECT * FROM person lEFT JOIN car USING (car_uid)')

# %%
cur.fetchall()
# Out:
# [('9857aa4a-6927-4285-82d7-45037dd053e7',
#   '9278fba4-609d-4961-94b1-538376a7880c',
#   'Teju',
#   'Lekan',
#   'lekanteju@gmail.com',
#   datetime.date(1990, 1, 9),
#   'Nigeria',
#   'Ford',
#   'High',
#   '? 20,000.00'),
#  ('3e8388a0-ec03-49fc-94f7-8bce1fdeb8e5',
#   '4506d922-07f0-455e-a470-884b3334469a',
#   'Ben',
#   'Fred',
#   'benfred@yahoo.com',
#   datetime.date(1997, 3, 1),
#   'Niger',
#   'Toyota',
#   'Camery',
#   '? 80,000.00'),
#  ('d46bf2bb-3f9c-42e3-99d1-bf805c0907af',
#   'f3ef8a00-4ceb-477f-aa31-388cbea1073b',
#   'Ladi',
#   'Magu',
#   None,
#   datetime.date(1999, 6, 7),
#   'Nigeria',
#   'Toyota',
#   'Corolla',
#   '? 72,000.00')]
